# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\dell\downloads\new folder\lib\site-packages (from sentence-transformers) (4.47.0)
# Requirement already satisfied: tqdm in c:\users\dell\downloads\new folder\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\dell\downloads\new folder\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\dell\downloads\new folder\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\dell\downloads\new folder\lib\site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\dell\downloads\new folder\lib\site-packages (from sentence-transformers) (0.26.5)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\dell\downloads\new folder\lib\site-packages (from sentence-transformers) (4.9.0)
# Requirement already satisfied: filelock in c:\users\dell\downloads\new folder\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dell\downloads\new folder\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\dell\downloads\new folder\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\downloads\new folder\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\dell\downloads\new folder\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: networkx in c:\users\dell\downloads\new folder\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\dell\downloads\new folder\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: sympy==1.13.1 in c:\users\dell\downloads\new folder\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dell\downloads\new folder\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\dell\downloads\new folder\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\downloads\new folder\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dell\downloads\new folder\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\dell\downloads\new folder\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\dell\downloads\new folder\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dell\downloads\new folder\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\downloads\new folder\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\downloads\new folder\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\downloads\new folder\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\downloads\new folder\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\downloads\new folder\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\downloads\new folder\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.2.2)
# Downloading sentence_transformers-5.2.0-py3-none-any.whl (493 kB)
#    ---------------------------------------- 0.0/493.7 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/493.7 kB 640.0 kB/s eta 0:00:01
#    ------------------- -------------------- 235.5/493.7 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  491.5/493.7 kB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 493.7/493.7 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-5.2.0

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import pickle

# %%
df = pd.read_csv("processed_reviews.csv")

df["review_text"] = df["review_text"].astype(str)
df = df[df["review_text"].str.strip().str.len() > 0]

corpus = df["review_text"].tolist()

print("Documents:", len(corpus))

if len(corpus) == 0:
    raise RuntimeError(
        "Corpus is empty. The HTML dataset does not contain usable review text. "
        "MiniLM retrieval cannot be executed."
    )

print("Sample review:\n", corpus[0][:300])
# Out:
# Documents: 61
# Sample review:
#  this dataset is an updated version of the

# %%
queries = [
    "battery life",
    "screen quality",
    "sound quality",
    "build quality",
    "camera performance"
]

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "false"

model = SentenceTransformer(
    "sentence-transformers/all-MiniLM-L6-v2",
    device="cpu"
)

print("MiniLM model loaded")
# Out:
# MiniLM model loaded

# %%
corpus_embeddings = model.encode(
    corpus,
    batch_size=32,
    show_progress_bar=False
)

print("Corpus embeddings shape:", corpus_embeddings.shape)

if corpus_embeddings.shape[0] == 0:
    raise RuntimeError("Embedding failed: no document embeddings created")
# Out:
# Corpus embeddings shape: (61, 384)

# %%
np.save("corpus_embeddings.npy", corpus_embeddings)
print("Saved corpus_embeddings.npy")
# Out:
# Saved corpus_embeddings.npy

# %%
def minilm_rank(embeddings, query, top_k=10):
    if embeddings.shape[0] == 0:
        raise ValueError("No embeddings available for ranking")

    query_emb = model.encode([query])[0]
    scores = embeddings @ query_emb

    return np.argsort(scores)[::-1][:top_k]

# %%
minilm_results = {}

for q in queries:
    minilm_results[q] = minilm_rank(corpus_embeddings, q)

minilm_results
# Out:
# {'battery life': array([24, 40, 26,  2, 57, 43,  3, 56, 25, 33], dtype=int64),
#  'screen quality': array([47, 21, 24, 26,  6,  2, 60, 41, 57, 36], dtype=int64),
#  'sound quality': array([24, 26, 21, 38,  2, 57, 56, 60, 47, 40], dtype=int64),
#  'build quality': array([24, 45, 50, 51, 20,  2, 26, 40, 21,  9], dtype=int64),
#  'camera performance': array([24, 21,  6, 26, 47, 40, 41,  2, 31, 56], dtype=int64)}

# %%
query = queries[0]
top_docs = minilm_results[query]

print("Query:", query)
print("\nTop retrieved reviews:\n")

for idx in top_docs[:3]:
    print("-", corpus[idx][:200], "\n")
# Out:
# Query: battery life
#
# Top retrieved reviews:
#
# - (34gb) - all 233.1 million reviews
#
# - - time of the review (unix time)
#
# - (14.3gb) - subset of the data in which all users and items have at least 5 reviews (75.26 million reviews)

# %%
with open("minilm_results.pkl", "wb") as f:
    pickle.dump(minilm_results, f)

print("Saved minilm_results.pkl")
# Out:
# Saved minilm_results.pkl
